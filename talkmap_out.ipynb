# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Requirement already satisfied: python-frontmatter in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (1.1.0)
# Requirement already satisfied: getorg in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (0.3.1)
# Requirement already satisfied: PyYAML in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from python-frontmatter) (6.0.3)
# Requirement already satisfied: geopy in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from getorg) (2.8.1)
# Requirement already satisfied: retrying in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from getorg) (1.4.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pynacl>=1.4.0 in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from pygithub->getorg) (1.6.2)
# Requirement already satisfied: requests>=2.14.0 in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from pygithub->getorg) (2.32.5)
# Requirement already satisfied: pyjwt>=2.4.0 in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from pygithub->getorg) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from pygithub->getorg) (2.6.2)
# Requirement already satisfied: cryptography>=3.4.0 in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.0.0)
# Requirement already satisfied: pycparser in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from requests>=2.14.0->pygithub->getorg) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/matthiasniehoff/.pyenv/versions/3.14.0/lib/python3.14/site-packages (from requests>=2.14.0->pygithub->getorg) (2025.11.12)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")

# %%
# Set the default timeout, in seconds
TIMEOUT = 5

# Prepare to geolocate
geocoder = Nominatim(user_agent="academicpages.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %% [markdown]
# In the event that this times out with an error, double check to make sure that the location is can be properly geolocated.

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()
    description = f"{title}<br />{venue}; {location}"

    if location.lower() == "online":
        continue

    # Geocode the location and report the status
    try:
        location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        print(description, location_dict[description])
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")
# Out:
# Can Data & ML really learn from software engineering?<br />voxxed days Brussels 2024; Brussels, Belgium Bruxelles - Brussel, Brussel-Hoofdstad - Bruxelles-Capitale, Région de Bruxelles-Capitale - Brussels Hoofdstedelijk Gewest, België / Belgique / Belgien
# Datenarchitekturen in der Realität<br />Software Architecture Alliance 2024; Munich, Germany München, Bayern, Deutschland
# Mit duckdb schell und einfach Daten analysieren – egal, wo sie gespeichert sind<br />data2day 2025; Karlsruhe, Germany Karlsruhe, Baden-Württemberg, Deutschland
# Modern Data Architectures need Software Engineering<br />WeAreDevelopers World Congress 2024; Berlin, Germany Berlin, Deutschland
# Datenarchitekturen in der Realität – Was passt bei uns?<br />data2day 2024; Heidelberg, Germany Heidelberg, Baden-Württemberg, Deutschland
# Lessons learned with Spark and Cassandra<br />Strata Data London 2017; London, United Kingdom Greater London, England, United Kingdom
# CQRS and Event Sourcing Applications with Cassandra<br />Cassandra Summit 2015; Santa Clara, CA Santa Clara, Santa Clara County, California, United States
# Analytics with Cassandra and Spark<br />Coding Serbia 2015; Novi Sad, Serbia Нови Сад, Град Нови Сад, Јужнобачки управни округ, Војводина, Србија
# Lessons learned with Spark and Cassandra<br />ApacheCon North America 2017; Miami, FL Miami, Miami-Dade County, Florida, United States
# Mit duckdb schell und einfach Daten analysieren - egal wo sie gespeichert sind<br />m3 Konferenz 2025; Karlsruhe, Germany Karlsruhe, Baden-Württemberg, Deutschland
# Analyze data easily with duckdb - and the implications on data architectures<br />pycon/pydata DE 2025; Darmstadt, Germany Darmstadt, Hessen, Deutschland
# Data Stream Processing Concepts and Implementations<br />ApacheCon North America 2017; Antwerp, Belgium Antwerpen, Vlaanderen, België / Belgique / Belgien
# Mit duckdb schell und einfach Daten analysieren – egal, wo sie gespeichert sind<br />IT Tage 2025; Frankfurt, Germany Frankfurt am Main, Hessen, Deutschland
# Data Aware Architectures als Basis für KI & Analytics<br />SQL Konferenz 2025; Hanau am Main, Germany Hanau, Ludwigstraße, Klein-Steinheim, Steinheim, Hanau, Hessen, 63456, Deutschland
# Reliable Data Flows and Scalable Platforms: Tackling Key Data Challenges<br />qcon 2025; London, United Kingdom Greater London, England, United Kingdom
# Data-Aware Architectures als Basis für Analytics & AI<br />OOP 2025; Munich, Germany München, Bayern, Deutschland
# Können wir wirklich vom Software Engineering lernen?<br />m3 Konferenz 2024; Köln, Germany Köln, Nordrhein-Westfalen, Deutschland
# DuckDB als schnelle, einfache und günstige SQL Engine<br />TDWI 2025; München, Germany München, Bayern, Deutschland
# Enjoying SQL data pipelines with dbt<br />WeAreDevelopers World Congress 2023; Berlin, Germany Berlin, Deutschland
# Moderne Datenarchitekturen: Was sind sie und wie werden sie umgesetzt?<br />Developer Week 2024; Nürnberg, Germany Nürnberg, Bayern, Deutschland
# Can Data & ML really learn from software engineering?<br />Øredev 2024; Malmö, Sweden Malmö, Malmö kommun, Skåne län, Sverige
# Data architectures in the real world<br />iSAQB Software Architecture Gathering 2024; Berlin, Germany Berlin, Deutschland
# Data pipelines, Documentation and Lineage with SQL & dbt<br />NDC Porto 2025; Porto, Portugal Porto, Portugal
# Data Aware Architectures als Basis für KI & Analytics<br />Developer Week 2025; Mannheim, Germany Mannheim, Baden-Württemberg, Deutschland
# Lessons learned with Spark and Cassandra<br />Cassandra Summit 2016; San Jose, CA San Jose, Santa Clara County, California, United States
# Datenanalysen zur Versorgungssicherheit – Eine Plattform für Fachleute und Data Engineers<br />data2day 2025; Karlsruhe, Germany Karlsruhe, Baden-Württemberg, Deutschland
# Data Aware Architectures als Basis für KI & Analytics<br />techcamp 2025; Hamburg, Germany Hamburg, Deutschland
# Simplicity in Data & ML<br />WeAreDevelopers World Congress 2024; Berlin, Germany Berlin, Deutschland
# Datenarchitekturen in der Realität<br />TDWI 2025; München, Germany München, Bayern, Deutschland
# Mit duckdb schell und einfach Daten analysieren - egal wo sie gespeichert sind<br />JavaLand 2025; Nürburg, Germany Nürburg, Adenau, Landkreis Ahrweiler, Rheinland-Pfalz, Deutschland

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
